# %% [markdown]
# # text

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


x = np.linspace(1, 10, 100)
y = np.cos(x)

plt.plot(x, y);

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


x = np.linspace(1, 10, 100)
y = np.cos(x)
y2 = np.sin(x)


plt.plot(x, y);
plt.plot(x, y2);

# %%
1+1
# Out:
# 2

# %% [markdown]
# tekst

# %%
np.random.rand(2,5)
# Out:
# array([[0.96147028, 0.81113225, 0.13134834, 0.6893945 , 0.42330861],
#        [0.32321334, 0.86079814, 0.73734983, 0.1681315 , 0.6500191 ]])
